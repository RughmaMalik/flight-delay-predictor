# %%
import pandas as pd

# %%
df = pd.read_csv(
    "../data/flight_data_2024.csv",
    on_bad_lines='skip',
    low_memory=False
)

print("Loaded rows:", len(df))

# %%
sample_df = df.sample(n=700000, random_state=42)

sample_df.to_csv("../data/flights_dataset.csv", index=False)

# %%
df = pd.read_csv("../data/flights_dataset.csv")
print(df.shape)
df.head()
